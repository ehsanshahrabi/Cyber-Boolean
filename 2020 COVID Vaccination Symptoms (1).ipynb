# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as mp
import os

# %%
covid = pd.read_csv('/Users/giannajimenez/Downloads/2020VAERSSYMPTOMS (1).csv')
df=pd.read_csv('/Users/giannajimenez/Downloads/2020VAERSSYMPTOMS (1).csv')
covid.head()
# Out:
#    VAERS_ID           SYMPTOM1  SYMPTOMVERSION1                SYMPTOM2  \
# 0    855017         Arthralgia             22.1                  Chills
# 1    855018             Chills             22.1                 Fatigue
# 2    855018  Muscular weakness             22.1       Pain in extremity
# 3    855019               Pain             22.1                Pruritus
# 4    855020             Chills             22.1  Influenza like illness
#
#    SYMPTOMVERSION2             SYMPTOM3  SYMPTOMVERSION3           SYMPTOM4  \
# 0             22.1  Injection site pain             22.1            Pyrexia
# 1             22.1         Hypertension             22.1      Hypoaesthesia
# 2             22.1              Pyrexia             22.1             Tremor
# 3             22.1                 Rash             22.1                NaN
# 4             22.1              Myalgia             22.1  Pain in extremity
#
#    SYMPTOMVERSION4                          SYMPTOM5  SYMPTOMVERSION5  \
# 0             22.1                               NaN              NaN
# 1             22.1  Injected limb mobility decreased             22.1
# 2             22.1                           Vertigo             22.1
# 3              NaN                               NaN              NaN
# 4             22.1                           Pyrexia             22.1
#
#    SYMPTOMS  OCCURENCE
# 0      Pain    21138.0
# 1  Erythema     7607.0
# 2   Pyrexia     6673.0
# 3  Headache     6301.0
# 4    Chills     5145.0

# %%
df.drop(columns = ['VAERS_ID','SYMPTOMVERSION1','SYMPTOMVERSION2','SYMPTOMVERSION3','SYMPTOMVERSION4','SYMPTOMVERSION5'], inplace=True)
df.head()
# Out:
#             SYMPTOM1                SYMPTOM2             SYMPTOM3  \
# 0         Arthralgia                  Chills  Injection site pain
# 1             Chills                 Fatigue         Hypertension
# 2  Muscular weakness       Pain in extremity              Pyrexia
# 3               Pain                Pruritus                 Rash
# 4             Chills  Influenza like illness              Myalgia
#
#             SYMPTOM4                          SYMPTOM5  SYMPTOMS  OCCURENCE
# 0            Pyrexia                               NaN      Pain    21138.0
# 1      Hypoaesthesia  Injected limb mobility decreased  Erythema     7607.0
# 2             Tremor                           Vertigo   Pyrexia     6673.0
# 3                NaN                               NaN  Headache     6301.0
# 4  Pain in extremity                           Pyrexia    Chills     5145.0

# %%
fig = plt.pie

sizes = [21138.0, 7607.0, 6673.0, 6301.0,5145,4647,4285,3461,3238,1983,1269,866,507]
labels = 'Pain', 'Erythema', 'Pyrexia', 'Headache','Chills', 'Fatigue','No adverse event','Dizziness', 'Pruritus','Arthralgia','Dyspnoea','Influenza like illness','Muscular weakness'
plt.pie(sizes,labels = labels)

plt.title('2020 COVID Vaccination Symptoms')
plt.axis('equal')
plt.savefig('demo.png', transparent=True)
plt.pie(colors=colors, shadow=True, autopct='%0.2f%%', textprops={'fontsize': 10})

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2l/vd2fby011zq_tpnkm908nq8c0000gn/T/ipykernel_42872/710102053.py in <module>
#       8 plt.axis('equal')
#       9 plt.savefig('demo.png', transparent=True)
# ---> 10 plt.pie(colors=colors, shadow=True, autopct='%0.2f%%', textprops={'fontsize': 10})
#      11
#      12 plt.show()
#
# TypeError: pie() missing 1 required positional argument: 'x'
