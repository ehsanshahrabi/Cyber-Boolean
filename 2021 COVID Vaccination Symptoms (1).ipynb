# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as mp
import os

# %%
covid = pd.read_csv('/Users/giannajimenez/Downloads/2021VAERSSYMPTOMS.csv')
df=pd.read_csv('/Users/giannajimenez/Downloads/2021VAERSSYMPTOMS.csv')
covid.head()
# Out:
# /var/folders/2l/vd2fby011zq_tpnkm908nq8c0000gn/T/ipykernel_47181/703441119.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   covid = pd.read_csv('/Users/giannajimenez/Downloads/2021VAERSSYMPTOMS.csv')
# /var/folders/2l/vd2fby011zq_tpnkm908nq8c0000gn/T/ipykernel_47181/703441119.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/Users/giannajimenez/Downloads/2021VAERSSYMPTOMS.csv')
#    VAERS_ID          SYMPTOM1  SYMPTOMVERSION1              SYMPTOM2  \
# 0    910642          Dyspnoea             25.0  Heart rate increased
# 1    916600         Dysphagia             23.1          Epiglottitis
# 2    916601           Anxiety             23.1              Dyspnoea
# 3    916602  Chest discomfort             23.1             Dysphagia
# 4    916603         Dizziness             23.1               Fatigue
#
#    SYMPTOMVERSION2                  SYMPTOM3  SYMPTOMVERSION3  \
# 0             25.0  SARS-CoV-2 test negative             25.0
# 1             23.1                       NaN              NaN
# 2             23.1                       NaN              NaN
# 3             23.1         Pain in extremity             23.1
# 4             23.1        Mobility decreased             23.1
#
#             SYMPTOM4  SYMPTOMVERSION4 SYMPTOM5  SYMPTOMVERSION5  SYMPTOMS  \
# 0                NaN              NaN      NaN              NaN      Pain
# 1                NaN              NaN      NaN              NaN  Erythema
# 2                NaN              NaN      NaN              NaN   Pyrexia
# 3  Visual impairment             23.1      NaN              NaN  Headache
# 4                NaN              NaN      NaN              NaN    Chills
#
#    OCCURENCE
# 0   329142.0
# 1    71493.0
# 2   109886.0
# 3   128532.0
# 4    93059.0

# %%
df.drop(columns = ['VAERS_ID','SYMPTOMVERSION1','SYMPTOMVERSION2','SYMPTOMVERSION3','SYMPTOMVERSION4','SYMPTOMVERSION5'], inplace=True)
df.head()
# Out:
#            SYMPTOM1              SYMPTOM2                  SYMPTOM3  \
# 0          Dyspnoea  Heart rate increased  SARS-CoV-2 test negative
# 1         Dysphagia          Epiglottitis                       NaN
# 2           Anxiety              Dyspnoea                       NaN
# 3  Chest discomfort             Dysphagia         Pain in extremity
# 4         Dizziness               Fatigue        Mobility decreased
#
#             SYMPTOM4 SYMPTOM5  SYMPTOMS  OCCURENCE
# 0                NaN      NaN      Pain   329142.0
# 1                NaN      NaN  Erythema    71493.0
# 2                NaN      NaN   Pyrexia   109886.0
# 3  Visual impairment      NaN  Headache   128532.0
# 4                NaN      NaN    Chills    93059.0

# %%
fig = plt.pie

sizes = [329142,71493,109886,128532,93059,106949,16081,71045,61088,43554,40940,9856,7179]
labels = 'Pain', 'Erythema', 'Pyrexia', 'Headache','Chills', 'Fatigue','No adverse event','Dizziness', 'Pruritus','Arthralgia','Dyspnoea','Influenza like illness','Muscular weakness'
plt.pie(sizes,labels = labels)

plt.title('2021 COVID Vaccination Symptoms')
plt.axis('equal')
plt.savefig('demo2.png', transparent=True)

plt.pie(colors=colors ,labels=labels, shadow=True,autopct='%0.2f%%', textprops={'fontsize': 10})
explode = explode

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2l/vd2fby011zq_tpnkm908nq8c0000gn/T/ipykernel_47181/2137753030.py in <module>
#       9 plt.savefig('demo2.png', transparent=True)
#      10
# ---> 11 plt.pie(colors=colors ,labels=labels, shadow=True,autopct='%0.2f%%', textprops={'fontsize': 10})
#      12 explode = explode
#      13
#
# NameError: name 'colors' is not defined
