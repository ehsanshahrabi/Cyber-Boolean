# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv("hospitalizations.csv")

# %%
data
# Out:
#     Age group   Month        Vaccine status   Rate
# 0     5-17 yr  Dec-21          Unvaccinated    3.9
# 1     5-17 yr  Jan-22          Unvaccinated   11.0
# 2     5-17 yr  Feb-22          Unvaccinated    5.0
# 3     5-17 yr  Mar-22          Unvaccinated    1.9
# 4     5-17 yr  Apr-22          Unvaccinated    1.7
# ..        ...     ...                   ...    ...
# 260    65+ yr  Nov-22            Vaccinated   93.4
# 261    65+ yr  Dec-22            Vaccinated  121.1
# 262    65+ yr  Oct-22  Vaccinated + Booster   26.2
# 263    65+ yr  Nov-22  Vaccinated + Booster   37.9
# 264    65+ yr  Dec-22  Vaccinated + Booster   49.4
#
# [265 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from a csv file
data = pd.read_csv("hospitalizations.csv")

# Filter data for 5-17 year age group
age_data_5_17 = data[data['Age group'] == '5-17 yr']

# Filter data for 18+ year age group
age_data_18 = data[data['Age group'] == '18+ yr']

# Filter data for 65+ year age group
age_data_65 = data[data['Age group'] == '65+ yr']

# Create a figure and axis object for 5-17 year age group
fig1, ax1 = plt.subplots(figsize=(10, 6))

# Create a bar chart for Unvaccinated rate
ax1.bar(age_data_5_17[age_data_5_17['Vaccine status'] == 'Unvaccinated']['Month'], age_data_5_17[age_data_5_17['Vaccine status'] == 'Unvaccinated']['Rate'], color='blue', label='Unvaccinated')

# Create a bar chart for Vaccinated rate
ax1.bar(age_data_5_17[age_data_5_17['Vaccine status'] == 'Vaccinated']['Month'], age_data_5_17[age_data_5_17['Vaccine status'] == 'Vaccinated']['Rate'], color='green', label='Vaccinated')

# Create a bar chart for Vaccinated + Booster rate
ax1.bar(age_data_5_17[age_data_5_17['Vaccine status'] == 'Vaccinated + Booster']['Month'], age_data_5_17[age_data_5_17['Vaccine status'] == 'Vaccinated + Booster']['Rate'], color='orange', label='Vaccinated + Booster')

# Set x-axis label and rotate
ax1.set_xlabel('Month')
ax1.tick_params(axis='x', labelrotation=90)

# Set y-axis label
ax1.set_ylabel('Rate of Hospitalizations')

# Set chart title
ax1.set_title('Hospitalizations for 5-17 year age group')

# Rotate x-axis tick labels to be vertical
ax1.set_xticklabels(age_data_5_17[age_data_5_17['Vaccine status'] == 'Unvaccinated']['Month'], rotation=90)

# Add legend
ax.legend()

# Display the chart
plt.show()
# Out:
# /var/folders/cg/2glgcgp90fl5k4qjs6b5_rrc0000gn/T/ipykernel_5128/1603194345.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(age_data_5_17[age_data_5_17['Vaccine status'] == 'Unvaccinated']['Month'], rotation=90)

# %%
# Create a figure and axis object for 18+ year age group
fig2, ax2 = plt.subplots(figsize=(10, 6))

# Create a bar chart for Unvaccinated rate
ax2.bar(age_data_18[age_data_18['Vaccine status'] == 'Unvaccinated']['Month'], age_data_18[age_data_18['Vaccine status'] == 'Unvaccinated']['Rate'], color='blue', label='Unvaccinated')

# Create a bar chart for Vaccinated rate
ax2.bar(age_data_18[age_data_18['Vaccine status'] == 'Vaccinated']['Month'], age_data_18[age_data_18['Vaccine status'] == 'Vaccinated']['Rate'], color='green', label='Vaccinated')

# Create a bar chart for Vaccinated + Booster rate
ax2.bar(age_data_18[age_data_18['Vaccine status'] == 'Vaccinated + Booster']['Month'], age_data_18[age_data_18['Vaccine status'] == 'Vaccinated + Booster']['Rate'], color='orange', label='Vaccinated + Booster')

# Set x-axis label and rotate
ax2.set_xlabel('Month')
ax2.tick_params(axis='x', labelrotation=90)

# Set y-axis label
ax2.set_ylabel('Rate of Hospitalizations')

# Set chart title
ax2.set_title('Hospitalizations for 18+ year age group')

# Add legend
ax2.legend()

# Display the chart
plt.show()
plt.savefig('demo.png', transparent=True)

# %%
# Create a figure and axis object for 65+ year age group
fig3, ax3 = plt.subplots(figsize=(10, 6))

# Create a bar chart for Unvaccinated rate
ax3.bar(age_data_65[age_data_65['Vaccine status'] == 'Unvaccinated']['Month'], age_data_65[age_data_65['Vaccine status'] == 'Unvaccinated']['Rate'], color='blue', label='Unvaccinated')

# Create a bar chart for Vaccinated rate
ax3.bar(age_data_65[age_data_65['Vaccine status'] == 'Vaccinated']['Month'], age_data_65[age_data_65['Vaccine status'] == 'Vaccinated']['Rate'], color='green', label='Vaccinated')

# Create a bar chart for Vaccinated + Booster rate
ax3.bar(age_data_65[age_data_65['Vaccine status'] == 'Vaccinated + Booster']['Month'], age_data_65[age_data_65['Vaccine status'] == 'Vaccinated + Booster']['Rate'], color='orange', label='Vaccinated + Booster')

# Set x-axis label and rotation
ax3.set_xlabel('Month')
ax3.tick_params(axis='x', labelrotation=90)

# Set y-axis label
ax3.set_ylabel('Rate of Hospitalizations')

# Set chart title
ax3.set_title('Hospitalizations for 65+ year age group')

# Add legend
ax3.legend(fontsize=12)

# Display the chart
plt.show()
plt.savefig('demo.png', transparent=True)
