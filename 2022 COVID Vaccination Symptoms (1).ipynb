# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as mp
import os

# %%
covid = pd.read_csv('/Users/giannajimenez/Downloads/2022VAERSSYMPTOMS.csv')
df=pd.read_csv('/Users/giannajimenez/Downloads/2022VAERSSYMPTOMS.csv')
covid.head()
# Out:
# /var/folders/2l/vd2fby011zq_tpnkm908nq8c0000gn/T/ipykernel_47445/3783276155.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   covid = pd.read_csv('/Users/giannajimenez/Downloads/2022VAERSSYMPTOMS.csv')
# /var/folders/2l/vd2fby011zq_tpnkm908nq8c0000gn/T/ipykernel_47445/3783276155.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/Users/giannajimenez/Downloads/2022VAERSSYMPTOMS.csv')
#    VAERS_ID                      SYMPTOM1  SYMPTOMVERSION1  \
# 0   1996873  Expired product administered             24.1
# 1   1996874            Suspected COVID-19             24.1
# 2   1996875               SARS-CoV-2 test             24.1
# 3   1996876                 Dysmenorrhoea             24.1
# 4   1996877      Heavy menstrual bleeding             24.1
#
#                    SYMPTOM2  SYMPTOMVERSION2                  SYMPTOM3  \
# 0          No adverse event             24.1                       NaN
# 1       Vaccination failure             24.1                       NaN
# 2        Suspected COVID-19             24.1       Vaccination failure
# 3  Heavy menstrual bleeding             24.1    Menstruation irregular
# 4           Oligomenorrhoea             24.1  SARS-CoV-2 test negative
#
#    SYMPTOMVERSION3 SYMPTOM4  SYMPTOMVERSION4 SYMPTOM5  SYMPTOMVERSION5  \
# 0              NaN      NaN              NaN      NaN              NaN
# 1              NaN      NaN              NaN      NaN              NaN
# 2             24.1      NaN              NaN      NaN              NaN
# 3             24.1      NaN              NaN      NaN              NaN
# 4             24.1      NaN              NaN      NaN              NaN
#
#    SYMPTOMS  OCCURENCE
# 0      Pain    68785.0
# 1  Erythema    10414.0
# 2   Pyrexia    19381.0
# 3  Headache    19385.0
# 4    Chills    11254.0

# %%
df.drop(columns = ['VAERS_ID','SYMPTOMVERSION1','SYMPTOMVERSION2','SYMPTOMVERSION3','SYMPTOMVERSION4','SYMPTOMVERSION5'], inplace=True)
df.head()
# Out:
#                        SYMPTOM1                  SYMPTOM2  \
# 0  Expired product administered          No adverse event
# 1            Suspected COVID-19       Vaccination failure
# 2               SARS-CoV-2 test        Suspected COVID-19
# 3                 Dysmenorrhoea  Heavy menstrual bleeding
# 4      Heavy menstrual bleeding           Oligomenorrhoea
#
#                    SYMPTOM3 SYMPTOM4 SYMPTOM5  SYMPTOMS  OCCURENCE
# 0                       NaN      NaN      NaN      Pain    68785.0
# 1                       NaN      NaN      NaN  Erythema    10414.0
# 2       Vaccination failure      NaN      NaN   Pyrexia    19381.0
# 3    Menstruation irregular      NaN      NaN  Headache    19385.0
# 4  SARS-CoV-2 test negative      NaN      NaN    Chills    11254.0

# %%
fig = plt.pie

sizes = [329142,71493,109886,128532,93059,106949,16081,71045,61088,43554,40940,9856,7179]
labels = 'Pain', 'Erythema', 'Pyrexia', 'Headache','Chills', 'Fatigue','No adverse event','Dizziness', 'Pruritus','Arthralgia','Dyspnoea','Influenza like illness','Muscular weakness'
plt.pie(sizes,labels = labels)

plt.title('2022 COVID Vaccination Symptoms')
plt.axis('equal')
plt.savefig('demo3.png', transparent=True)

plt.pie(colors=colors ,labels=labels, shadow=True,autopct='%0.2f%%', textprops={'fontsize': 10})
explode = explode

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2l/vd2fby011zq_tpnkm908nq8c0000gn/T/ipykernel_47445/3644246625.py in <module>
#       9 plt.savefig('demo3.png', transparent=True)
#      10
# ---> 11 plt.pie(colors=colors ,labels=labels, shadow=True,autopct='%0.2f%%', textprops={'fontsize': 10})
#      12 explode = explode
#      13
#
# NameError: name 'colors' is not defined
